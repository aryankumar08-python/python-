# %%
import matplotlib 
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.title('First plot')
plt.xlabel('abc')
plt.ylabel('pqr')
plt.show()

# %%
x=[10,20,30,40,50]
y=[3,8,12,18,25]
plt.plot(x,y)
plt.title("Monthly Revenue")
plt.xlabel("Months")
plt.ylabel("Revenue")
plt.show()

# %%
fig, ax = plt.subplots()

x=[10,20,30,40,50]
y=[3,8,12,18,25]

ax.plot(x, y)
ax.set_title("Sales")
ax.set_xlabel("Month")
ax.set_ylabel("Revenue")

plt.show()

# %%
import pandas as pd
sales_data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Revenue": [120000, 135000, 128000, 145000, 160000, 170000],
    "Profit": [20000, 25000, 23000, 28000, 35000, 40000],
    "Expenses": [100000, 110000, 105000, 117000, 125000, 130000]
}
df=pd.DataFrame(sales_data)
fig,axes = plt.subplots(2,2,figsize=(5,3))
axes[0,0].plot(df['Month'],df['Revenue'],marker='o',markersize=7,markerfacecolor='red',alpha=1)#linestyle='-.',linewidth=2,color='Red')#alpha is used for transperancy
axes[0,0].set_title("Revenue vs Month")
axes[0,1].plot(df['Month'],df['Profit'])
axes[0,1].set_title('Profit vs Month')
axes[1,1].plot(df['Month'],df['Expenses'])
axes[1,1].set_title('Expenses vs Month')

plt.show()

# %%
sales_data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Revenue": [120000, 135000, 128000, 145000, 160000, 170000]
    }
df=pd.DataFrame(sales_data)

fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df['Month'],df['Revenue'],label='Revenue')
ax.set_title("Revenue vs Month")
ax.set_xlabel('Month')
ax.set_ylabel('Revenue')
ax.legend()
ax.grid(True)
plt.show()

# %%
sales_data = {
    "Product": ["Laptop", "Phone", "Tablet", "Monitor", "Keyboard"],
    "Sales": [500, 800, 350, 450, 300]
}
df=pd.DataFrame(sales_data)
fig,ax=plt.subplots()
ax.set_title('Product vs sales')
ax.set_xlabel('Product')
ax.set_ylabel('Sales')
ax.bar(
    df['Product'],
    df['Sales']
)
ax.grid(True)

# %%
sales_data = {
    "Product": ["Laptop", "Phone", "Tablet", "Monitor", "Keyboard"],
    "Sales": [500, 800, 350, 450, 300]
}
df=pd.DataFrame(sales_data)
fig,ax=plt.subplots()
ax.set_title('Product vs sales')
ax.set_xlabel('Product')
ax.set_ylabel('Sales')
ax.barh(
    df['Product'],
    df['Sales'],
    color='Red'
)
ax.grid(True)

# %%
sales_data = {
    "Product": ["Laptop", "Phone", "Tablet", "Monitor", "Keyboard"],
    "Sales": [500, 800, 350, 450, 300]
}
df=pd.DataFrame(sales_data)
fig,axes=plt.subplots(2,2)
axes[1,1].bar(
    df['Product'],
    df['Sales']
)
axes[1,0].plot(
    df['Product'],
    df['Sales']
)
